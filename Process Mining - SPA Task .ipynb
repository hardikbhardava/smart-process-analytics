# %%
# Importing Python Libraries

import pm4py
import pandas as pd
import os
import pm4py

from pm4py.objects.petri.importer import importer as pnml_importer
# Out:
# C:\Users\Ahmed Fazal\anaconda3\lib\site-packages\pm4py\objects\petri\__init__.py:19: UserWarning: please use the pm4py.objects.petri_net package instead.
#   warnings.warn('please use the pm4py.objects.petri_net package instead.')
# C:\Users\Ahmed Fazal\anaconda3\lib\site-packages\pm4py\objects\petri\obj.py:19: UserWarning: pm4py.objects.petri.obj is deprecated. Please use the class pm4py.objects.petri_net.obj instead.
#   warnings.warn("pm4py.objects.petri.obj is deprecated. Please use the class pm4py.objects.petri_net.obj instead.")
# C:\Users\Ahmed Fazal\anaconda3\lib\site-packages\pm4py\objects\petri\exporter\__init__.py:21: UserWarning: please use the pm4py.objects.petri_net.exporter package instead.
#   warnings.warn('please use the pm4py.objects.petri_net.exporter package instead.')
# C:\Users\Ahmed Fazal\anaconda3\lib\site-packages\pm4py\objects\petri\importer\__init__.py:21: UserWarning: please use the pm4py.objects.petri_net.importer package instead.
#   warnings.warn('please use the pm4py.objects.petri_net.importer package instead.')

# %%
# Importing the PNML file as a Petri net

process_model, initial_marking, final_marking = pnml_importer.apply("C:/Users/Ahmed Fazal/Downloads/PN_IM pnml file.pnml")

# %%
#  Visualizing the process model by running process instance

from pm4py.visualization.petri_net import visualizer as pn_visualizer
gviz = pn_visualizer.apply(process_model, initial_marking, final_marking)
pn_visualizer.view(gviz)
print(process_model)
# Out:
# places: [ n1, n10, n11, n12, n13, n14, n15, n16, n17, n18, n19, n2, n20, n21, n22, n23, n24, n25, n26, n27, n28, n29, n3, n30, n31, n32, n33, n34, n35, n36, n37, n38, n39, n4, n40, n41, n42, n43, n44, n45, n46, n47, n48, n49, n5, n50, n51, n52, n53, n54, n55, n56, n57, n58, n59, n6, n60, n61, n62, n63, n64, n7, n8, n9 ]
# transitions: [ (n100, None), (n101, 'Vendor creates invoice'), (n102, None), (n103, 'SRM: Deleted'), (n104, None), (n105, 'Release Purchase Order'), (n106, None), (n107, 'Receive Order Confirmation'), (n108, None), (n109, None), (n110, None), (n111, None), (n112, 'Record Service Entry Sheet'), (n113, 'Cancel Goods Receipt'), (n114, 'Change Quantity'), (n115, 'Delete Purchase Order Item'), (n116, 'Block Purchase Order Item'), (n117, 'Record Subsequent Invoice'), (n118, 'Cancel Subsequent Invoice'), (n119, None), (n120, None), (n121, None), (n122, None), (n123, 'Change Approval for Purchase Order'), (n124, None), (n125, 'Set Payment Block'), (n126, None), (n127, 'Cancel Invoice Receipt'), (n128, None), (n129, 'Vendor creates debit memo'), (n130, None), (n131, 'Remove Payment Block'), (n132, None), (n133, 'Change Final Invoice Indicator'), (n134, 'SRM: Transaction Completed'), (n135, 'SRM: Complete'), (n136, 'SRM: Document Completed'), (n137, 'SRM: Change was Transmitted'), (n138, 'Change Storage Location'), (n139, 'SRM: Transfer Failed (E.Sys.)'), (n140, 'Update Order Confirmation'), (n141, 'Change Currency'), (n142, 'Change Rejection Indicator'), (n65, None), (n66, None), (n67, 'Create Purchase Order Item'), (n68, None), (n69, 'SRM: Created'), (n70, None), (n71, 'SRM: Incomplete'), (n72, 'SRM: Held'), (n73, None), (n74, None), (n75, None), (n76, 'Change Price'), (n77, None), (n78, 'Reactivate Purchase Order Item'), (n79, 'Record Goods Receipt'), (n80, None), (n81, 'SRM: In Transfer to Execution Syst.'), (n82, None), (n83, 'SRM: Ordered'), (n84, None), (n85, 'SRM: Awaiting Approval'), (n86, None), (n87, 'Change Delivery Indicator'), (n88, None), (n89, 'Create Purchase Requisition Item'), (n90, None), (n91, 'Release Purchase Requisition'), (n92, None), (n93, 'Change payment term'), (n94, None), (n95, None), (n96, 'Record Invoice Receipt'), (n97, None), (n98, None), (n99, 'Clear Invoice') ]
# arcs: [ (n100, None)->n38, (n101, 'Vendor creates invoice')->n40, (n102, None)->n42, (n103, 'SRM: Deleted')->n42, (n104, None)->n44, (n105, 'Release Purchase Order')->n44, (n106, None)->n46, (n107, 'Receive Order Confirmation')->n46, (n108, None)->n48, (n109, None)->n49, (n109, None)->n57, (n110, None)->n48, (n111, None)->n52, (n112, 'Record Service Entry Sheet')->n51, (n113, 'Cancel Goods Receipt')->n51, (n114, 'Change Quantity')->n51, (n115, 'Delete Purchase Order Item')->n51, (n116, 'Block Purchase Order Item')->n51, (n117, 'Record Subsequent Invoice')->n51, (n118, 'Cancel Subsequent Invoice')->n51, (n119, None)->n52, (n120, None)->n50, (n121, None)->n53, (n121, None)->n55, (n122, None)->n50, (n123, 'Change Approval for Purchase Order')->n54, (n124, None)->n56, (n125, 'Set Payment Block')->n56, (n126, None)->n58, (n127, 'Cancel Invoice Receipt')->n58, (n128, None)->n60, (n129, 'Vendor creates debit memo')->n60, (n130, None)->n62, (n131, 'Remove Payment Block')->n62, (n132, None)->n37, (n133, 'Change Final Invoice Indicator')->n37, (n134, 'SRM: Transaction Completed')->n37, (n135, 'SRM: Complete')->n63, (n136, 'SRM: Document Completed')->n64, (n137, 'SRM: Change was Transmitted')->n33, (n138, 'Change Storage Location')->n33, (n139, 'SRM: Transfer Failed (E.Sys.)')->n29, (n140, 'Update Order Confirmation')->n29, (n141, 'Change Currency')->n29, (n142, 'Change Rejection Indicator')->n29, (n65, None)->n3, (n65, None)->n5, (n65, None)->n7, (n66, None)->n2, (n67, 'Create Purchase Order Item')->n4, (n68, None)->n6, (n69, 'SRM: Created')->n6, (n70, None)->n9, (n71, 'SRM: Incomplete')->n10, (n72, 'SRM: Held')->n9, (n73, None)->n11, (n73, None)->n13, (n73, None)->n15, (n73, None)->n17, (n73, None)->n19, (n73, None)->n21, (n73, None)->n23, (n73, None)->n25, (n73, None)->n27, (n74, None)->n8, (n75, None)->n12, (n76, 'Change Price')->n12, (n77, None)->n14, (n78, 'Reactivate Purchase Order Item')->n14, (n79, 'Record Goods Receipt')->n16, (n80, None)->n18, (n81, 'SRM: In Transfer to Execution Syst.')->n18, (n82, None)->n20, (n83, 'SRM: Ordered')->n20, (n84, None)->n22, (n85, 'SRM: Awaiting Approval')->n22, (n86, None)->n24, (n87, 'Change Delivery Indicator')->n24, (n88, None)->n26, (n89, 'Create Purchase Requisition Item')->n26, (n90, None)->n29, (n91, 'Release Purchase Requisition')->n29, (n92, None)->n30, (n93, 'Change payment term')->n30, (n94, None)->n31, (n94, None)->n33, (n95, None)->n28, (n96, 'Record Invoice Receipt')->n32, (n97, None)->n35, (n97, None)->n39, (n97, None)->n41, (n97, None)->n43, (n97, None)->n45, (n97, None)->n47, (n97, None)->n59, (n97, None)->n61, (n98, None)->n34, (n99, 'Clear Invoice')->n36, n1->(n65, None), n10->(n72, 'SRM: Held'), n11->(n75, None), n11->(n76, 'Change Price'), n12->(n74, None), n13->(n77, None), n13->(n78, 'Reactivate Purchase Order Item'), n14->(n74, None), n15->(n79, 'Record Goods Receipt'), n16->(n74, None), n17->(n80, None), n17->(n81, 'SRM: In Transfer to Execution Syst.'), n18->(n74, None), n19->(n82, None), n19->(n83, 'SRM: Ordered'), n20->(n74, None), n21->(n84, None), n21->(n85, 'SRM: Awaiting Approval'), n22->(n74, None), n23->(n86, None), n23->(n87, 'Change Delivery Indicator'), n24->(n74, None), n25->(n88, None), n25->(n89, 'Create Purchase Requisition Item'), n26->(n74, None), n27->(n90, None), n27->(n91, 'Release Purchase Requisition'), n28->(n139, 'SRM: Transfer Failed (E.Sys.)'), n28->(n140, 'Update Order Confirmation'), n28->(n141, 'Change Currency'), n28->(n142, 'Change Rejection Indicator'), n28->(n74, None), n29->(n92, None), n29->(n93, 'Change payment term'), n3->(n67, 'Create Purchase Order Item'), n30->(n94, None), n31->(n96, 'Record Invoice Receipt'), n32->(n95, None), n33->(n97, None), n34->(n135, 'SRM: Complete'), n34->(n138, 'Change Storage Location'), n34->(n95, None), n35->(n99, 'Clear Invoice'), n36->(n98, None), n37->(n98, None), n38->(n132, None), n38->(n133, 'Change Final Invoice Indicator'), n38->(n134, 'SRM: Transaction Completed'), n39->(n101, 'Vendor creates ...

# %%
# Defining place, transition and arc of a petrinet with respect to process model

places = process_model.places
transitions = process_model.transitions
arcs = process_model.arcs

# %%
# Importing the BPI_Challenge event log in XES format

from pm4py.objects.log.importer.xes import importer as xes_importer
log = xes_importer.apply('C:/Users/Ahmed Fazal/Downloads/BPI_Challenge_2019.xes')
# Out:
# HBox(children=(HTML(value='parsing log, completed traces :: '), FloatProgress(value=0.0, max=251734.0), HTML(v…

# %%
# Discovering BPMN model by conversion from process tree to BPMN

process_tree = pm4py.discover_process_tree_inductive(log)
bpmn_model = pm4py.convert_to_bpmn(process_tree)
pm4py.view_bpmn(bpmn_model)

# %%
# Fetching the events from the log file

log_events=[]
for i in range(1,33):
  event_list=[]
  for j in range(0,len(log[i])):
    event_list.append(log[i][j]['concept:name'])
  log_events.append(event_list)

# %%
# Number of events in the log

len(log_events)
# Out:
# 32

# %%
log_events[0]
# Out:
# ['SRM: Created',
#  'SRM: Complete',
#  'SRM: Awaiting Approval',
#  'SRM: Document Completed',
#  'SRM: Ordered',
#  'SRM: In Transfer to Execution Syst.',
#  'SRM: Change was Transmitted',
#  'Create Purchase Order Item',
#  'Vendor creates invoice',
#  'Record Goods Receipt',
#  'Record Service Entry Sheet',
#  'Record Invoice Receipt',
#  'Clear Invoice',
#  'SRM: In Transfer to Execution Syst.',
#  'SRM: Transfer Failed (E.Sys.)']

# %%
# Implementing N-grams for the business process model 

import nltk #importing natural language toolkit

result=[]

n_gram_val = []
nexT_event = []
prob = []
predict_event = []

# Defining function for process prediction and passing process model and log file as parameters

def calculating_n_grams(event_list, n, log_events):
    
    predict=[]
  
    for i in range(n):
        
        if (n > 0):
            
            n_grams=nltk.ngrams(event_list,n)
            
            print(n_grams)
            for seq in list(n_grams):
            
            
        
                n_element = seq[len(seq)-1]
        
        for i in range(len(log_events)):
            
      
            if set(seq).issubset(log_events[i]) == True:
            
        
                next_event=(log_events[i].index(n_element)+1) # Getting next possible tasks from current task

                predicted_event=log_events[i][next_event]
          
                predict.append(predicted_event) 
            
                #print(predict, " predict ")

            occured_events = dict((x,predict.count(x)) for x in set(predict)) #dictionary to count occurance of events
      
        for k, v in occured_events.items():
            
            
            print(n, " -- " ,k, " -- ", v)
            if n<0:
                 break
                    
            else:
                
                n_gram_val.append(n)
                
                nexT_event.append(k)
                
                prob.append(v / sum(occured_events.values()))
                
                predict_event.append(max(predict, key=predict.count))
                
                
                result.append([n,k,(v / sum(occured_events.values())),(max(predict, key=predict.count))])
  
            n -= 1 



# Enter the number of process for prediction
n_value = input("Enter the desired N value")
n_value = int(n_value)



event_list = ['SRM: Created',
  'SRM: Complete',
  'SRM: Awaiting Approval',
  'SRM: Document Completed'
  ]



calculating_n_grams(event_list, n_value ,log_events) #running the n-gram function for prediction

# Final probabilities of the events from the event log
df = pd.DataFrame(result, columns=['N_value','Next_events','Probability','predicted event'])
# Out:
# Enter the desired N value3
# <generator object ngrams at 0x0000015CBC999F90>
# 3  --  SRM: In Transfer to Execution Syst.  --  24
# 2  --  SRM: Ordered  --  8
# <generator object ngrams at 0x0000015CBC999200>
# 1  --  SRM: In Transfer to Execution Syst.  --  48
# 0  --  SRM: Ordered  --  16
# -1  --  SRM: In Transfer to Execution Syst.  --  72

# %%
n_gram_val
# Out:
# [3, 2, 1, 0]

# %%
prob
# Out:
# [0.75, 0.25, 0.75, 0.25]

# %%
df.set_index('N_value', inplace=True)

# %%
df
# Out:
#                                  Next_events  Probability  \
# N_value
# 3        SRM: In Transfer to Execution Syst.         0.75
# 2                               SRM: Ordered         0.25
# 1        SRM: In Transfer to Execution Syst.         0.75
# 0                               SRM: Ordered         0.25
#
#                              predicted event
# N_value
# 3        SRM: In Transfer to Execution Syst.
# 2        SRM: In Transfer to Execution Syst.
# 1        SRM: In Transfer to Execution Syst.
# 0        SRM: In Transfer to Execution Syst.

# %%
type(result)
# Out:
# list

# %% [markdown]
# # FINAL RESULT

# %%
spa = pd.pivot_table(df, index=["N_value"],columns=["predicted event","Next_events"])

# %%
spa
# Out:
#                                         Probability
# predicted event SRM: In Transfer to Execution Syst.
# Next_events     SRM: In Transfer to Execution Syst. SRM: Ordered
# N_value
# 0                                               NaN         0.25
# 1                                              0.75          NaN
# 2                                               NaN         0.25
# 3                                              0.75          NaN

# %%
spa = spa.sort_values('N_value',axis=0, ascending=False)

# %%
spa
# Out:
#                                         Probability
# predicted event SRM: In Transfer to Execution Syst.
# Next_events     SRM: In Transfer to Execution Syst. SRM: Ordered
# N_value
# 3                                              0.75          NaN
# 2                                               NaN         0.25
# 1                                              0.75          NaN
# 0                                               NaN         0.25
